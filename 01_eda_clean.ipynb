# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %% [markdown]
# ### Load data

# %%
DATA_PATH=Path('data/AB_NYC_2019.csv')
df=pd.read_csv(DATA_PATH)
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Basic eda

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  str
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  str
#  4   neighbourhood_group             48895 non-null  str
#  5   neighbourhood                   48895 non-null  str
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  str
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ### Null in percent

# %%
(df.isnull().mean()*100).round(2)
# Out:
# id                                 0.00
# name                               0.03
# host_id                            0.00
# host_name                          0.04
# neighbourhood_group                0.00
# neighbourhood                      0.00
# latitude                           0.00
# longitude                          0.00
# room_type                          0.00
# price                              0.00
# minimum_nights                     0.00
# number_of_reviews                  0.00
# last_review                       20.56
# reviews_per_month                 20.56
# calculated_host_listings_count     0.00
# availability_365                   0.00
# dtype: float64

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df['room_type'].unique()
# Out:
# <StringArray>
# ['Private room', 'Entire home/apt', 'Shared room']
# Length: 3, dtype: str

# %%
df['neighbourhood_group'].unique()
# Out:
# <StringArray>
# ['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx']
# Length: 5, dtype: str

# %%
df['neighbourhood'].unique()
# Out:
# <StringArray>
# [        'Kensington',            'Midtown',             'Harlem',
#        'Clinton Hill',        'East Harlem',        'Murray Hill',
#  'Bedford-Stuyvesant',     'Hell's Kitchen',    'Upper West Side',
#           'Chinatown',
#  ...
#      'Fort Wadsworth',           'Rosebank',          'Unionport',
#          'Mill Basin',      'Arden Heights',        'Bull's Head',
#            'New Dorp',          'Rossville',       'Breezy Point',
#         'Willowbrook']
# Length: 221, dtype: str

# %% [markdown]
# ### Check duplicated

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
df[df.duplicated('id')]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# ### host_id can be duplicated!

# %%
df[df.duplicated('host_id')]
# Out:
#              id                                             name    host_id  \
# 22         8025                         CBG Helps Haiti Room#2.5      22486
# 23         8110                            CBG Helps Haiti Rm #2      22486
# 33         9783                              back room/bunk beds      32294
# 35        10962  Lovely room 2 & garden; Best area, Legal rental       9744
# 39        12048              LowerEastSide apt share shortterm 1       7549
# ...         ...                                              ...        ...
# 48887  36483152  Garden Jewel Apartment in Williamsburg New York  208514239
# 48889  36484363                               QUIT PRIVATE HOUSE  107716952
# 48890  36484665  Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057    Affordable room in Bushwick/East Williamsburg    6570630
# 48893  36485609             43rd St. Time Square-cozy single bed   30985759
#
# ...

# %% [markdown]
# ## fill NaN value

# %% [markdown]
# ### reminder

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df['reviews_per_month']=df['reviews_per_month'].fillna(0)
df['reviews_per_month'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['last_review']=pd.to_datetime(df['last_review'],errors='coerce')
reference_date = df['last_review'].max()
df['days_since_last_review'] = (reference_date - df['last_review']).dt.days
df['days_since_last_review'] = df['days_since_last_review'].fillna(-1)  
df['has_reviews'] = df['number_of_reviews'].gt(0).astype(int)

# %% [markdown]
# ### Drop unnecessary columns

# %%
df=df.drop(['id','host_name','last_review'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            48879 non-null  str
#  1   host_id                         48895 non-null  int64
#  2   neighbourhood_group             48895 non-null  str
#  3   neighbourhood                   48895 non-null  str
#  4   latitude                        48895 non-null  float64
#  5   longitude                       48895 non-null  float64
#  6   room_type                       48895 non-null  str
#  7   price                           48895 non-null  int64
#  8   minimum_nights                  48895 non-null  int64
#  9   number_of_reviews               48895 non-null  int64
#  10  reviews_per_month               48895 non-null  float64
#  11  calculated_host_listings_count  48895 non-null  int64
# ...

# %% [markdown]
# ## basic data visualization (Check for outliers)

# %%
plt.figure(figsize=(7,5))
sns.boxplot(data=df,x='neighbourhood_group',y='price',hue='neighbourhood_group')
plt.title('Prices by Neighbourhood (neighbourhood_group)')
plt.xlabel('Neighbourhood')
plt.ylabel('Prices')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distribution of the price variable

# %%
f, axes = plt.subplots(1, 2,figsize=(12, 4))
sns.histplot(data=df, x=df['price'],bins=80  , ax=axes[0])
axes[0].set_title('Price distribution (raw)')
axes[0].set_xlabel('Price')
sns.histplot(data=df, x=df['price'].clip(upper=1000), bins=80 , ax=axes[1])
axes[1].set_xscale('log')
axes[1].set_title('Price distribution (log scale (cut off at $1000))')
axes[1].set_xlabel('Price (log)')
# Out:
# Text(0.5, 0, 'Price (log)')

# %% [markdown]
# ### Basic IQR

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR=Q3 - Q1

low_bound = Q1 - 1.5 * IQR
high_bound = Q3 + 1.5 * IQR

print(IQR)
print(low_bound)
print(high_bound)
# Out:
# 106.0
# -90.0
# 334.0

# %%
df[df['price']==0].shape
# Out:
# (11, 15)

# %%
df= df[df['price'] > 0]

# %%
df['minimum_nights'].describe()
# Out:
# count    48884.000000
# mean         7.029887
# std         20.512224
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %%
sns.boxplot(data=df,x='neighbourhood_group',y='minimum_nights',hue='neighbourhood_group',log_scale=True)
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='minimum_nights'>

# %%
df[df['minimum_nights']==0]
# Out:
# Empty DataFrame
# Columns: [name, host_id, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365, days_since_last_review, has_reviews]
# Index: []

# %% [markdown]
# ### Listing type distribution and price impact

# %%
plt.figure(figsize=(8, 8))
df['room_type'].value_counts().plot.bar(color='steelblue')
plt.title('Listing number by room type')
plt.ylabel('Piece')
plt.tick_params(axis='x', rotation=0)

# %%
plt.figure(figsize=(8, 8))
sns.boxplot(data=df, x='room_type', y='price',hue='room_type', legend=False)

plt.yscale('log')
plt.title('Price by room type (log scale)')
plt.ylabel('Price (log)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Geographic Distribution (NYC Map)

# %%
num_cols = df.select_dtypes(include=np.number).columns

plt.figure(figsize=(10, 8))
sns.heatmap(df[num_cols].corr(), annot=True, fmt='.2f',cmap='coolwarm', center=0, square=True,vmax=1,vmin=-1,)
plt.title('Correlation heatmap (numeric variables)')
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 48884 entries, 0 to 48894
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            48868 non-null  str
#  1   host_id                         48884 non-null  int64
#  2   neighbourhood_group             48884 non-null  str
#  3   neighbourhood                   48884 non-null  str
#  4   latitude                        48884 non-null  float64
#  5   longitude                       48884 non-null  float64
#  6   room_type                       48884 non-null  str
#  7   price                           48884 non-null  int64
#  8   minimum_nights                  48884 non-null  int64
#  9   number_of_reviews               48884 non-null  int64
#  10  reviews_per_month               48884 non-null  float64
#  11  calculated_host_listings_count  48884 non-null  int64
# ...

# %%
df.to_csv('data/CLEAN_AB_NYC_2019.csv',index=False)
